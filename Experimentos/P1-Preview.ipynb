# %% [markdown]
# # Nueva sección

# %%
from pandas import DataFrame, read_csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = '/content/drive/My Drive/2019-1/Simulation of System and Laboratory/Final Project/Code/defaultofcreditcardclients.xls'
df = pd.read_excel(file)
df.head()
# Out:
#   Unnamed: 0         X1   X2  ...       X22       X23                           Y
# 0         ID  LIMIT_BAL  SEX  ...  PAY_AMT5  PAY_AMT6  default payment next month
# 1          1      20000    2  ...         0         0                           1
# 2          2     120000    2  ...         0      2000                           1
# 3          3      90000    2  ...      1000      5000                           0
# 4          4      50000    2  ...      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
data = df.values
unicos = data[:,-1]
unos = np.where(unicos == 1)
lenU =len(unos[0])
cero = np.where(unicos == 0)
lenC=len(cero[0])
lenU, lenC
# Out:
# (6636, 23364)

# %%
df= df.iloc[1:]
df['X2'].describe()
df
# Out:
#       Unnamed: 0      X1 X2 X3 X4  X5  ...     X19    X20    X21     X22    X23  Y
# 1              1   20000  2  2  1  24  ...     689      0      0       0      0  1
# 2              2  120000  2  2  2  26  ...    1000   1000   1000       0   2000  1
# 3              3   90000  2  2  2  34  ...    1500   1000   1000    1000   5000  0
# 4              4   50000  2  2  1  37  ...    2019   1200   1100    1069   1000  0
# 5              5   50000  1  2  1  57  ...   36681  10000   9000     689    679  0
# 6              6   50000  1  1  2  37  ...    1815    657   1000    1000    800  0
# 7              7  500000  1  1  2  29  ...   40000  38000  20239   13750  13770  0
# 8              8  100000  2  2  2  23  ...     601      0    581    1687   1542  0
# 9              9  140000  2  3  1  28  ...       0    432   1000    1000   1000  0
# 10            10   20000  1  3  2  35  ...       0      0  13007    1122      0  0
# ...

# %%
df['X2'].describe()

#dos = len(np.where(df['X2'].values == 2)[0])
#dos
# Out:
# count     30000
# unique        2
# top           2
# freq      18112
# Name: X2, dtype: int64

# %%
#df['X1'].describe()
df['X1'].values.min()
# Out:
# 10000

# %%
df['X3'].describe()
# Out:
# count     30000
# unique        7
# top           2
# freq      14030
# Name: X3, dtype: int64

# %%
data = df['X4']

c = np.where(data ==3)
len(c[0])
# Out:
# 323
